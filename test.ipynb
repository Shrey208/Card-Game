# %%
import warnings
warnings.filterwarnings('ignore')
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
#!jupyter nbextension enable --py widgetsnbextension --sys-prefix
#!jupyter serverextension enable voila --sys-prefix

# %%
# %run main.ipynb
# Out:
#            Name                                            Crystal
# 0     Alignment                                               good
# 1  Intelligence                                                 63
# 2      Strength                                                 16
# 3         Speed                                                 12
# 4    Durability                                                 14
# 5         Power                                                 57
# 6        Combat                                                 56
# 7         Total                                                218
# 8     Abilities  Super Strength, Stamina, Super Speed, Element ...
#            Name                                           Songbird
# 0     Alignment                                               good
# 1  Intelligence                                                 75
# 2      Strength                                                 36
# 3         Speed                                                 27
# 4    Durability                                                 42
# 5         Power                                                 55
# 6        Combat                                                 56
# 7         Total                                                291
# 8     Abilities  Agility, Durability, Flight, Super Strength, S...
